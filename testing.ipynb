# %%
import torch, os
import torch.nn as nn
import torch.optim as optim
import torchvision.datasets as datasets
import torch.utils.data as data
import torchvision.transforms as transforms
import torchvision.models as models
from train_model import train_model
from test_model import test_model
# %matplotlib inline

# %%
data_dir = 'tiny-images/'
num_workers = {'train' : 4,'val'   : 0,'test'  : 0}
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomRotation(20),
        transforms.RandomHorizontalFlip(0.5),
        transforms.ToTensor(),
        transforms.Resize(224),
        transforms.Normalize([0.4802, 0.4481, 0.3975], [0.2302, 0.2265, 0.2262]),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize(224),
        transforms.Normalize([0.4802, 0.4481, 0.3975], [0.2302, 0.2265, 0.2262]),
    ]),
    'test': transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize(224),
        transforms.Normalize([0.4802, 0.4481, 0.3975], [0.2302, 0.2265, 0.2262]),
    ])
}
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) 
                  for x in ['train', 'val','test']}
dataloaders = {x: data.DataLoader(image_datasets[x], batch_size=100, shuffle=False, num_workers=num_workers[x])
                  for x in ['train', 'val', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val', 'test']}

# %%
model = models.resnet18()
model.avgpool = nn.AdaptiveAvgPool2d(1)
model.fc.out_features = 200
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.load_state_dict(torch.load('models/224/model_10_epoch.pt', map_location=device))
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

test_model(model, dataloaders, dataset_sizes, criterion, optimizer, phases=['val'])
# Out:
# Iteration: 1/100, Loss: 44.255492091178894.Running corrects: 87/100
#
# Iteration: 2/100, Loss: 200.26464462280273.Running corrects: 42/100
#
# Iteration: 3/100, Loss: 195.12858390808105.Running corrects: 50/100
#
# Iteration: 4/100, Loss: 108.98988246917725.Running corrects: 78/100
#
# Iteration: 5/100, Loss: 113.1702184677124.Running corrects: 75/100
#
# Iteration: 6/100, Loss: 111.78959608078003.Running corrects: 70/100
#
# Iteration: 7/100, Loss: 95.64816355705261.Running corrects: 78/100
#
# Iteration: 8/100, Loss: 128.11332941055298.Running corrects: 65/100
#
# Iteration: 9/100, Loss: 113.72027397155762.Running corrects: 70/100
#
# Iteration: 10/100, Loss: 146.6173529624939.Running corrects: 62/100
#
# Iteration: 11/100, Loss: 108.71661901473999.Running corrects: 71/100
#
# Iteration: 12/100, Loss: 57.514458894729614.Running corrects: 83/100
#
# Iteration: 13/100, Loss: 96.09923362731934.Running corrects: 77/100
#
# Iteration: 14/100, Loss: 141.75066947937012.Running corrects: 64/100
#
# Iteration: 15/100, Loss: 154.69467639923096.Running corrects: 67/100
#
# Iteration: 16/100, Loss: 103.83858680725098.Running corrects: 71/100
#
# Iteration: 17/100, Loss: 164.60191011428833.Running corrects: 50/100
#
# Iteration: 18/100, Loss: 93.53951215744019.Running corrects: 74/100
#
# Iteration: 19/100, Loss: 85.54471731185913.Running corrects: 77/100
#
# Iteration: 20/100, Loss: 81.93722367286682.Running corrects: 71/100
#
# Iteration: 21/100, Loss: 174.4570016860962.Running corrects: 56/100
#
# Iteration: 22/100, Loss: 137.8464937210083.Running corrects: 61/100
#
# Iteration: 23/100, Loss: 67.57414937019348.Running corrects: 84/100
#
# Iteration: 24/100, Loss: 105.13284206390381.Running corrects: 69/100
#
# Iteration: 25/100, Loss: 158.31925868988037.Running corrects: 57/100
#
# Iteration: 26/100, Loss: 90.44990539550781.Running corrects: 78/100
#
# Iteration: 27/100, Loss: 90.78518748283386.Running corrects: 77/100
#
# Iteration: 28/100, Loss: 94.0459132194519.Running corrects: 74/100
#
# Iteration: 29/100, Loss: 107.4373722076416.Running corrects: 75/100
#
# Iteration: 30/100, Loss: 90.85214734077454.Running corrects: 81/100
#
# Iteration: 31/100, Loss: 137.96429634094238.Running corrects: 64/100
#
# Iteration: 32/100, Loss: 217.05613136291504.Running corrects: 52/100
#
# Iteration: 33/100, Loss: 204.15189266204834.Running corrects: 53/100
#
# Iteration: 34/100, Loss: 170.87315320968628.Running corrects: 56/100
#
# Iteration: 35/100, Loss: 162.7439260482788.Running corrects: 59/100
#
# Iteration: 36/100, Loss: 143.36493015289307.Running corrects: 57/100
#
# Iteration: 37/100, Loss: 93.44046711921692.Running corrects: 71/100
#
# Iteration: 38/100, Loss: 119.27516460418701.Running corrects: 70/100
#
# Iteration: 39/100, Loss: 185.50854921340942.Running corrects: 60/100
#
# Iteration: 40/100, Loss: 159.09600257873535.Running corrects: 64/100
#
# Iteration: 41/100, Loss: 135.47298908233643.Running corrects: 71/100
#
# Iteration: 42/100, Loss: 203.3541202545166.Running corrects: 53/100
#
# Iteration: 43/100, Loss: 199.0317702293396.Running corrects: 51/100
#
# Iteration: 44/100, Loss: 150.1423478126526.Running corrects: 64/100
#
# Iteration: 45/100, Loss: 198.18508625030518.Running corrects: 51/100
#
# Iteration: 46/100, Loss: 110.74764728546143.Running corrects: 72/100
#
# Iteration: 47/100, Loss: 108.15130472183228.Running corrects: 76/100
#
# Iteration: 48/100, Loss: 131.24607801437378.Running corrects: 62/100
#
# Iteration: 49/100, Loss: 120.498526096344.Running corrects: 70/100
#
# Iteration: 50/100, Loss: 138.21340799331665.Running corrects: 71/100
#
# Iteration: 51/100, Loss: 138.76277208328247.Running corrects: 65/100
#
# Iteration: 52/100, Loss: 102.78743505477905.Running corrects: 77/100
#
# Iteration: 53/100, Loss: 176.53785943984985.Running corrects: 53/100
#
# Iteration: 54/100, Loss: 132.6826810836792.Running corrects: 69/100
#
# Iteration: 55/100, Loss: 62.40867376327515.Running corrects: 89/100
#
# Iteration: 56/100, Loss: 119.65153217315674.Running corrects: 75/100
#
# Iteration: 57/100, Loss: 170.55872678756714.Running corrects: 55/100
#
# Iteration: 58/100, Loss: 138.8100028038025.Running corrects: 66/100
#
# Iteration: 59/100, Loss: 147.7162003517151.Running corrects: 67/100
#
# Iteration: 60/100, Loss: 183.52057933807373.Running corrects: 55/100
#
# Iteration: 61/100, Loss: 134.14994478225708.Running corrects: 64/100
#
# Iteration: 62/100, Loss: 186.54255867004395.Running corrects: 58/100
#
# Iteration: 63/100, Loss: 126.24030113220215.Running corrects: 65/100
#
# Iteration: 64/100, Loss: 115.10653495788574.Running corrects: 68/100
#
# Iteration: 65/100, Loss: 115.14811515808105.Running corrects: 73/100
#
# Iteration: 66/100, Loss: 177.18114852905273.Running corrects: 53/100
#
# Iteration: 67/100, Loss: 177.80832052230835.Running corrects: 54/100
#
# Iteration: 68/100, Loss: 190.49763679504395.Running corrects: 54/100
#
# Iteration: 69/100, Loss: 158.8046431541443.Running corrects: 64/100
#
# Iteration: 70/100, Loss: 219.39456462860107.Running corrects: 50/100
#
# Iteration: 71/100, Loss: 142.55374670028687.Running corrects: 65/100
#
# Iteration: 72/100, Loss: 132.59731531143188.Running corrects: 73/100
#
# Iteration: 73/100, Loss: 85.75783371925354.Running corrects: 80/100
#
# Iteration: 74/100, Loss: 114.31189775466919.Running corrects: 73/100
#
# Iteration: 75/100, Loss: 113.44050168991089.Running corrects: 77/100
#
# Iteration: 76/100, Loss: 170.64526081085205.Running corrects: 61/100
#
# Iteration: 77/100, Loss: 89.47871327400208.Running corrects: 76/100
#
# Iteration: 78/100, Loss: 140.87237119674683.Running corrects: 67/100
#
# Iteration: 79/100, Loss: 178.47051620483398.Running corrects: 61/100
#
# Iteration: 80/100, Loss: 239.18132781982422.Running corrects: 36/100
#
# Iteration: 81/100, Loss: 112.04421520233154.Running corrects: 69/100
#
# Iteration: 82/100, Loss: 112.27014064788818.Running corrects: 68/100
#
# Iteration: 83/100, Loss: 88.28480243682861.Running corrects: 78/100
#
# Iteration: 84/100, Loss: 77.42072939872742.Running corrects: 79/100
#
# Iteration: 85/100, Loss: 251.73380374908447.Running corrects: 47/100
#
# Iteration: 86/100, Loss: 87.81572580337524.Running corrects: 76/100
#
# Iteration: 87/100, Loss: 148.6129879951477.Running corrects: 65/100
#
# Iteration: 88/100, Loss: 198.9629864692688.Running corrects: 46/100
#
# Iteration: 89/100, Loss: 129.03786897659302.Running corrects: 69/100
#
# Iteration: 90/100, Loss: 162.98396587371826.Running corrects: 54/100
#
# Iteration: 91/100, Loss: 164.57535028457642.Running corrects: 65/100
#
# Iteration: 92/100, Loss: 124.410080909729.Running corrects: 61/100
#
# Iteration: 93/100, Loss: 90.75875878334045.Running corrects: 79/100
#
# Iteration: 94/100, Loss: 120.03903388977051.Running corrects: 69/100
#
# Iteration: 95/100, Loss: 108.33401679992676.Running corrects: 75/100
#
# Iteration: 96/100, Loss: 113.54434490203857.Running corrects: 65/100
#
# Iteration: 97/100, Loss: 82.7470064163208.Running corrects: 78/100
#
# Iteration: 98/100, Loss: 139.81659412384033.Running corrects: 61/100
#
# Iteration: 99/100, Loss: 133.80839824676514.Running corrects: 61/100
#
# Iteration: 100/100, Loss: 187.36064434051514.Running corrects: 50/100
#
#
# Test Loss: 1.3568 Acc: 0.6599
# Total corrects: 6599/10000
#
# ----------
# Test complete in 14m 4s
